# %% [markdown]
# # What we gonna do in this notebook
# 1. Preprocessing And Cleaning
# 2. Train Test Split
# 3. TFIDF or BOW (Sentences ---> Vectors)
# 4. Trained Our Model

# %%
import pandas as pd

# %%
messages = pd.read_csv('../SpamClassifier\smsSpamcollection\SMSSpamCollection',
                        sep='\t',
                        names=['label','message'])

# %%
messages
# Out:
#      label                                            message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham               Will ü b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %% [markdown]
# ### Data Cleaning And preprocessing

# %%
import re 
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Ayush
# [nltk_data]     Kashyap\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
corpus = []
for i in range(0,len(messages)):
    review=re.sub('[^a-zA-Z]',' ',messages['message'][i])
    review=review.lower()
    review=review.split()
    review=[ps.stem(word) for word in review if not word in stopwords.words('english')]
    review=' '.join(review)
    corpus.append(review)

# %% [markdown]
# ### Output Features

# %%
y = pd.get_dummies(messages['label'])
y=y.iloc[:,0].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(corpus,y,test_size=0.20)

# %% [markdown]
# ## Creating TFIDF Model

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tv = TfidfVectorizer(max_features=2500,ngram_range=(1,2))

# %% [markdown]
# ### Input Feature

# %%
# Independent Features
X_train= tv.fit_transform(X_train).toarray()
X_test= tv.fit_transform(X_test).toarray()

# %%
tv.vocabulary_
# Out:
# {'ye': np.int64(2482),
#  'seri': np.int64(1837),
#  'babe': np.int64(101),
#  'want': np.int64(2192),
#  'dont': np.int64(409),
#  'babi': np.int64(103),
#  'im': np.int64(780),
#  'thing': np.int64(2031),
#  'fanci': np.int64(507),
#  'rude': np.int64(1777),
#  'time': np.int64(2050),
#  'sexi': np.int64(1842),
#  'go': np.int64(627),
#  'slo': np.int64(1879),
#  'hard': np.int64(704),
#  'txt': np.int64(2115),
#  'xxx': np.int64(2474),
#  'msg': np.int64(1058),
#  'lol': np.int64(921),
#  'would': np.int64(2459),
#  'mom': np.int64(1040),
#  'fit': np.int64(541),
#  'tell': np.int64(1998),
#  'whole': np.int64(2310),
#  'famili': np.int64(506),
#  'crazi': np.int64(333),
#  'terribl': np.int64(2006),
#  'whole famili': np.int64(2312),
#  'sm': np.int64(1885),
#  'ac': np.int64(5),
#  'jsco': np.int64(827),
#  'high': np.int64(729),
#  'may': np.int64(980),
#  'know': np.int64(849),
#  'channel': np.int64(237),
#  'day': np.int64(359),
#  'ur': np.int64(2137),
#  'psychic': np.int64(1529),
#  'repli': np.int64(1692),
#  'an': np.int64(52),
#  'question': np.int64(1541),
#  'end': np.int64(454),
#  'sm ac': np.int64(1886),
#  'day ur': np.int64(365),
#  'psychic repli': np.int64(1530),
#  'repli an': np.int64(1693),
#  'repli end': np.int64(1699),
#  'red': np.int64(1620),
#  'blood': np.int64(145),
#  'heart': np.int64(712),
#  'send': np.int64(1826),
#  'ti': np.int64(2043),
#  'friend': np.int64(582),
#  'includ': np.int64(787),
#  'like': np.int64(905),
#  'get': np.int64(606),
#  'back': np.int64(104),
#  'poor': np.int64(1373),
#  'relat': np.int64(1645),
#  'need': np.int64(1081),
#  'support': np.int64(1964),
#  'frnd': np.int64(589),
#  'mani': np.int64(966),
#  'luv': np.int64(954),
#  'pray': np.int64(1442),
#  'god': np.int64(639),
#  'tri': np.int64(2096),
#  'red red': np.int64(1624),
#  'red blood': np.int64(1621),
#  'ur friend': np.int64(2140),
#  'get back': np.int64(608),
#  'poor relat': np.int64(1376),
#  'relat need': np.int64(1646),
#  'pray god': np.int64(1444),
#  'friendship': np.int64(585),
#  'poem': np.int64(1335),
#  'dear': np.int64(369),
#  'near': np.int64(1079),
#  'hear': np.int64(709),
#  'fear': np.int64(517),
#  'live': np.int64(916),
#  'cheer': np.int64(246),
#  'tear': np.int64(1993),
#  'alway': np.int64(43),
#  'gud': np.int64(678),
#  'ni': np.int64(1099),
#  'friendship poem': np.int64(586),
#  'poem dear': np.int64(1336),
#  'dear dear': np.int64(371),
#  'dear near': np.int64(373),
#  'near hear': np.int64(1080),
#  'hear dont': np.int64(710),
#  'dont get': np.int64(411),
#  'get fear': np.int64(612),
#  'fear live': np.int64(518),
#  'live cheer': np.int64(917),
#  'cheer tear': np.int64(247),
#  'tear alway': np.int64(1994),
#  'alway dear': np.int64(45),
#  'dear gud': np.int64(372),
#  'gud ni': np.int64(680),
#  'meet': np.int64(988),
#  'librari': np.int64(899),
#  'oh': np.int64(1129),
#  'rite': np.int64(1765),
#  'well': np.int64(2289),
#  'best': np.int64(130),
#  'mate': np.int64(971),
#  'pete': np.int64(1187),
#  'went': np.int64(2295),
#  'week': np.int64(2262),
#  'longer': np.int64(923),
#  'well im': np.int64(2290),
#  'week geva': np.int64(2271),
#  'offic': np.int64(1127),
#  'da': np.int64(351),
#  'win': np.int64(2336),
#  'year': np.int64(2487),
#  'cd': np.int64(232),
#  'store': np.int64(1944),
#  'worth': np.int64(2456),
#  'enter': np.int64(462),
#  'weekli': np.int64(2285),
#  'draw': np.int64(419),
#  'music': np.int64(1065),
#  'ts': np.int64(2104),
#  'cs': np.int64(337),
#  'www': np.int64(2464),
#  'ldew': np.int64(876),
#  'com': np.int64(284),
#  'sub': np.int64(1954),
#  'ppmx': np.int64(1423),
#  'win year': np.int64(2354),
#  'weekli draw': np.int64(2287),
#  'draw txt': np.int64(421),
#  'txt music': np.int64(2118),
#  'ts cs': np.int64(2105),
#  'cs www': np.int64(339),
#  'www ldew': np.int64(2465),
#  'ldew com': np.int64(877),
#  'win ppmx': np.int64(2346),
#  'ok': np.int64(1131),
#  'imma': np.int64(781),
#  'definit': np.int64(378),
#  'restock': np.int64(1745),
#  'let': np.int64(892),
#  'restock thanksgiv': np.int64(1746),
#  'let know': np.int64(893),
#  'leav': np.int64(884),
#  'de': np.int64(367),
#  'start': np.int64(1931),
#  'prepar': np.int64(1456),
#  'next': np.int64(1098),
#  'prepar next': np.int64(1457),
#  'home': np.int64(749),
#  'chat': np.int64(243),
#  'alway chat': np.int64(44),
#  'saturday': np.int64(1795),
#  'sunday': np.int64(1961),
#  'holiday': np.int64(745),
#  'difficult': np.int64(394),
#  'wast': np.int64(2204),
#  'wanna': np.int64(2190),
#  'wast da': np.int64(2205),
#  'aight': np.int64(29),
#  'wat': np.int64(2206),
#  'happen': np.int64(696),
#  'side': np.int64(1856),
#  'wat happen': np.int64(2211),
#  'love': np.int64(935),
#  'brother': np.int64(171),
#  'talk': np.int64(1985),
#  'grin': np.int64(665),
#  'say': np.int64(1800),
#  'hey': np.int64(721),
#  'hello': np.int64(718),
#  'across': np.int64(13),
#  'sea': np.int64(1811),
#  'say hello': np.int64(1801),
#  'across sea': np.int64(14),
#  'anytim': np.int64(61),
#  'lor': np.int64(926),
#  'email': np.int64(452),
#  'low': np.int64(944),
#  'cost': np.int64(322),
#  'prescripiton': np.int64(1460),
#  'listen': np.int64(914),
#  'call': np.int64(189),
#  'prescripiton drvgsto': np.int64(1461),
#  'good': np.int64(646),
#  'today': np.int64(2062),
#  'hope': np.int64(754),
#  'mayb': np.int64(982),
#  'interview': np.int64(799),
#  'wake': np.int64(2184),
#  'miss': np.int64(1018),
#  'kiss': np.int64(846),
#  'today hope': np.int64(2064),
#  'hope good': np.int64(755),
#  'wake miss': np.int64(2185),
#  'miss babe': np.int64(1019),
#  'kiss across': np.int64(847),
#  'collect': np.int64(277),
#  'laptop': np.int64(864),
#  'collect ur': np.int64(280),
#  'ur laptop': np.int64(2141),
#  'sorri': np.int64(1907),
#  'bed': np.int64(120),
#  'earli': np.int64(442),
#  'went bed': np.int64(2297),
#  'alright': np.int64(40),
#  'guy': np.int64(682),
#  'watch': np.int64(2221),
#  'tv': np.int64(2111),
#  'izzit': np.int64(811),
#  'thk': np.int64(2036),
#  'us': np.int64(2152),
#  'watch tv': np.int64(2231),
#  'wat izzit': np.int64(2212),
#  'date': np.int64(357),
#  'water': np.int64(2233),
#  'log': np.int64(920),
#  'water log': np.int64(2234),
#  'movi': np.int64(1053),
#  'tonight': np.int64(2078),
#  'prob': np.int64(1513),
#  'watch movi': np.int64(2228),
#  'home earli': np.int64(750),
#  'happi': np.int64(699),
#  'new': np.int64(1094),
#  'see': np.int64(1816),
#  'happi new': np.int64(703),
#  'new year': np.int64(1096),
#  'man': np.int64(963),
#  'thought': np.int64(2039),
#  'great': np.int64(662),
#  'number': np.int64(1120),
#  'ill': np.int64(779),
#  'appreci': np.int64(69),
#  'safe': np.int64(1787),
#  'great day': np.int64(663),
#  'day send': np.int64(364),
#  'santa': np.int64(1791),
#  'littl': np.int64(915),
#  'one': np.int64(1140),
#  'xma': np.int64(2471),
#  'eve': np.int64(478),
#  'book': np.int64(153),
#  'keep': np.int64(836),
#  'ten': np.int64(2002),
#  'rs': np.int64(1775),
#  'buy': np.int64(182),
#  'two': np.int64(2114),
#  'egg': np.int64(447),
#  'drug': np.int64(428),
#  'anymor': np.int64(59),
#  'need drug': np.int64(1084),
#  'set': np.int64(1841),
#  'place': np.int64(1240),
#  'mind': np.int64(1012),
#  'forget': np.int64(561),
#  'rememb': np.int64(1660),
#  'wish': np.int64(2368),
#  'valentin': np.int64(2157),
#  'place heart': np.int64(1245),
#  'rememb wish': np.int64(1667),
#  'wish happi': np.int64(2376),
#  'valentin day': np.int64(2158),
#  'haha': np.int64(688),
#  'receipt': np.int64(1587),
#  'sound': np.int64(1910),
#  'gd': np.int64(603),
#  'luck': np.int64(949),
#  'receipt sound': np.int64(1591),
#  'femal': np.int64(524),
#  'throw': np.int64(2041),
#  'decid': np.int64(375),
#  'sad': np.int64(1782),
#  'stori': np.int64(1946),
#  'last': np.int64(866),
#  'wife': np.int64(2325),
#  'nt': np.int64(1117),
#  'parent': np.int64(1168),
#  'forgot': np.int64(562),
#  'kid': np.int64(841),
#  'work': np.int64(2450),
#  'even': np.int64(479),
#  'colleagu': np.int64(275),
#  'cabin': np.int64(187),
#  'pa': np.int64(1163),
#  'said': np.int64(1788),
#  'boss': np.int64(156),
#  'felt': np.int64(522),
#  'special': np.int64(1915),
#  'askd': np.int64(82),
#  'lunch': np.int64(951),
#  'invit': np.int64(800),
#  'apart': np.int64(64),
#  'minut': np.int64(1014),
#  'came': np.int64(211),
#  'wid': np.int64(2316),
#  'scream': np.int64(1809),
#  'surpris': np.int64(1971),
#  'wait': np.int64(2180),
#  'nake': np.int64(1071),
#  'sad stori': np.int64(1783),
#  'stori man': np.int64(1947),
#  'man last': np.int64(964),
#  'last week': np.int64(867),
#  'week day': np.int64(2267),
#  'day wife': np.int64(366),
#  'wife nt': np.int64(2328),
#  'nt wish': np.int64(1118),
#  'wish parent': np.int64(2381),
#  'parent forgot': np.int64(1169),
#  'forgot kid': np.int64(563),
#  'kid went': np.int64(842),
#  'went work': np.int64(2299),
#  'work even': np.int64(2451),
#  'even colleagu': np.int64(480),
#  'colleagu wish': np.int64(276),
#  'wish enter': np.int64(2373),
#  'enter cabin': np.int64(463),
#  'cabin pa': np.int64(188),
#  'pa said': np.int64(1164),
#  'said happi': np.int64(1789),
#  'happi day': np.int64(701),
#  'day boss': np.int64(362),
#  'boss felt': np.int64(157),
#  'felt special': np.int64(523),
#  'special askd': np.int64(1916),
#  'askd lunch': np.int64(83),
#  'lunch lunch': np.int64(953),
#  'lunch invit': np.int64(952),
#  'invit apart': np.int64(801),
#  'apart went': np.int64(65),
#  'wid cake': np.int64(2317),
#  'wife parent': np.int64(2329),
#  'troubl': np.int64(2101),
#  'convinc': np.int64(316),
#  'tel': np.int64(1997),
#  'twice': np.int64(2113),
#  'read': np.int64(1552),
#  'accept': np.int64(6),
#  'sister': np.int64(1866),
#  'lover': np.int64(942),
#  'clo': np.int64(265),
#  'lvblefrnd': np.int64(955),
#  'jstfrnd': np.int64(828),
#  'cutefrnd': np.int64(349),
#  'lifpartnr': np.int64(901),
#  'belovd': np.int64(126),
#  'swtheart': np.int64(1978),
#  'bstfrnd': np.int64(174),
#  'rpli': np.int64(1773),
#  'mean': np.int64(984),
#  'enemi': np.int64(455),
#  'today accept': np.int64(2063),
#  'accept day': np.int64(8),
#  'day accept': np.int64(361),
#  'accept brother': np.int64(7),
#  'brother sister': np.int64(172),
#  'sister lover': np.int64(1867),
#  'lover dear': np.int64(943),
#  'dear best': np.int64(370),
#  'best clo': np.int64(131),
#  'clo lvblefrnd': np.int64(266),
#  'lvblefrnd jstfrnd': np.int64(956),
#  'jstfrnd cutefrnd': np.int64(829),
#  'cutefrnd lifpartnr': np.int64(350),
#  'lifpartnr belovd': np.int64(902),
#  'belovd swtheart': np.int64(127),
#  'swtheart bstfrnd': np.int64(1979),
#  'bstfrnd rpli': np.int64(175),
#  'rpli mean': np.int64(1774),
#  'mean enemi': np.int64(985),
#  'pick': np.int64(1195),
#  'flower': np.int64(550),
#  'touch': np.int64(2085),
#  'gift': np.int64(619),
#  'hold': np.int64(742),
#  'make': np.int64(961),
#  'import': np.int64(782),
#  'much': np.int64(1063),
#  'life': np.int64(900),
#  'wish hold': np.int64(2377),
#  'late': np.int64(868),
#  'late need': np.int64(870),
#  'go get': np.int64(630),
#  'kick': np.int64(840),
#  'euro': np.int64(477),
#  'kept': np.int64(839),
#  'latest': np.int64(873),
#  'news': np.int64(1097),
#  'result': np.int64(1747),
#  'daili': np.int64(354),
#  'remov': np.int64(1673),
#  'stop': np.int64(1940),
#  'result daili': np.int64(1749),
#  'remov send': np.int64(1675),
#  'txt stop': np.int64(2122),
#  'argument': np.int64(74),
#  'situat': np.int64(1868),
#  'lose': np.int64(929),
#  'person': np.int64(1186),
#  'amp': np.int64(48),
#  'correct': np.int64(321),
#  'win situat': np.int64(2348),
#  'black': np.int64(142),
#  'shirt': np.int64(1846),
#  'blue': np.int64(148),
#  'urgent': np.int64(2147),
#  'mobil': np.int64(1026),
#  'award': np.int64(97),
#  'prize': np.int64(1500),
#  'guarante': np.int64(676),
#  'land': np.int64(857),
#  'line': np.int64(909),
#  'claim': np.int64(256),
#  'valid': np.int64(2159),
#  'hr': np.int64(766),
#  'ppm': np.int64(1420),
#  'urgent mobil': np.int64(2149),
#  'mobil number': np.int64(1033),
#  'number award': np.int64(1121),
#  'award prize': np.int64(99),
#  'prize guarante': np.int64(1504),
#  'guarante call': np.int64(677),
#  'call land': np.int64(196),
#  'land line': np.int64(858),
#  'line claim': np.int64(910),
#  'claim valid': np.int64(261),
#  'valid hr': np.int64(2160),
#  'hr ppm': np.int64(767),
#  'figur': np.int64(526),
#  'suppos': np.int64(1965),
#  'coupl': np.int64(330),
#  'differ': np.int64(393),
#  'peopl': np.int64(1180),
#  'togeth': np.int64(2067),
#  'week said': np.int64(2273),
#  'free': np.int64(566),
#  'messag': np.int64(999),
#  'without': np.int64(2396),
#  'recharg': np.int64(1609),
#  'hi': np.int64(727),
#  'free messag': np.int64(571),
#  'without recharg': np.int64(2398),
#  'recharg hi': np.int64(1610),
#  'hi hi': np.int64(728),
#  'sup': np.int64(1963),
#  'point': np.int64(1337),
#  'project': np.int64(1517),
#  'hour': np.int64(762),
#  'take': np.int64(1981),
#  'max': np.int64(978),
#  'easi': np.int64(443),
#  'pick variou': np.int64(1198),
#  'point go': np.int64(1339),
#  'done': np.int64(408),
#  'connect': np.int64(309),
#  'slow': np.int64(1880),
#  'later': np.int64(871),
#  'first': np.int64(539),
#  'tomo': np.int64(2069),
#  'tri later': np.int64(2098),
#  'priya': np.int64(1498),
#  'right': np.int64(1755),
#  'doctor': np.int64(405),
#  'priya right': np.int64(1499),
#  'dun': np.int64(433),
#  'wan': np.int64(2187),
#  'alreadi': np.int64(39),
#  'ah': np.int64(28),
#  'still': np.int64(1937),
#  'eat': np.int64(445),
#  'dun wan': np.int64(437),
#  'wat still': np.int64(2218),
#  'den': np.int64(383),
#  'that': np.int64(2026),
#  'thesi': np.int64(2030),
#  'tough': np.int64(2086),
#  'someth': np.int64(1901),
#  'exam': np.int64(490),
#  'cancel': np.int64(214),
#  'yeah': np.int64(2484),
#  'understand': np.int64(2130),
#  'give': np.int64(624),
#  'ring': np.int64(1757),
#  'fone': np.int64(555),
#  'kate': np.int64(834),
#  'mm': np.int64(1022),
#  'ask': np.int64(81),
#  'come': np.int64(285),
#  'enough': np.int64(461),
#  'havent': np.int64(707),
#  'yet': np.int64(2493),
#  'thank': np.int64(2021),
#  'rington': np.int64(1758),
#  'order': np.int64(1157),
#  'ref': np.int64(1629),
#  'charg': np.int64(240),
#  'tone': np.int64(2074),
#  'arriv': np.int64(76),
#  'pleas': np.int64(1270),
#  'custom': np.int64(344),
#  'servic': np.int64(1838),
#  'thank rington': np.int64(2023),
#  'rington order': np.int64(1760),
#  'ref number': np.int64(1630),
#  'number mobil': np.int64(1123),
#  'mobil charg': np.int64(1027),
#  'charg tone': np.int64(241),
#  'tone arriv': np.int64(2075),
#  'arriv pleas': np.int64(77),
#  'pleas call': np.int64(1273),
#  'call custom': np.int64(193),
#  'custom servic': np.int64(347),
#  'sweet': np.int64(1972),
#  'morn': np.int64(1048),
#  'welcom': np.int64(2288),
#  'enjoy': np.int64(459),
#  'full': np.int64(591),
#  'joy': np.int64(825),
#  'mrng': np.int64(1056),
#  'gud mrng': np.int64(679),
#  'gym': np.int64(685),
#  'wanna gym': np.int64(2191),
#  'boy': np.int64(161),
#  'father': np.int64(514),
#  'power': np.int64(1412),
#  'power frndship': np.int64(1413),
#  'ho': np.int64(741),
#  'big': np.int64(136),
#  'laugh': np.int64(874),
#  'ya': np.int64(2476),
#  'see ya': np.int64(1818),
#  'chanc': np.int64(234),
#  'chanc win': np.int64(235),
#  'win free': np.int64(2340),
#  'repli back': np.int64(1694),
#  'catch': np.int64(229),
#  'put': np.int64(1537),
#  'valu': np.int64(2161),
#  'advis': np.int64(19),
#  'follow': np.int64(553),
#  'recent': np.int64(1604),
#  'review': np.int64(1751),
#  'mob': np.int64(1024),
#  'bonu': np.int64(151),
#  'valu custom': np.int64(2162),
#  'custom pleas': np.int64(346),
#  'pleas advis': np.int64(1271),
#  'advis follow': np.int64(20),
#  'follow recent': np.int64(554),
#  'recent review': np.int64(1605),
#  'review mob': np.int64(1752),
#  'mob award': np.int64(1025),
#  'award bonu': np.int64(98),
#  'bonu prize': np.int64(152),
#  'prize call': np.int64(1501),
#  'goe': np.int64(641),
#  'fine': np.int64(535),
#  'find': np.int64(530),
#  'job': np.int64(818),
#  'prospect': np.int64(1522),
#  'boytoy': np.int64(162),
#  'teas': np.int64(1995),
#  'hello love': np.int64(719),
#  'goe day': np.int64(642),
#  'wish well': np.int64(2383),
#  'job prospect': np.int64(819),
#  'prospect miss': np.int64(1523),
#  'teas kiss': np.int64(1996),
#  'month': np.int64(1045),
#  'dont know': np.int64(412),
#  'freemsg': np.int64(576),
#  'got': np.int64(658),
#  'video': np.int64(2165),
#  'pic': np.int64(1194),
#  'wild': np.int64(2334),
#  'hurri': np.int64(772),
#  'bore': np.int64(155),
#  'rcvd': np.int64(1548),
#  'freemsg hey': np.int64(577),
#  'repli wild': np.int64(1713),
#  'wild txt': np.int64(2335),
#  'stop stop': np.int64(1942),
#  'uncl': np.int64(2127),
#  'atlanta': np.int64(84),
#  'semest': np.int64(1824),
#  'uncl atlanta': np.int64(2128),
#  'atlanta wish': np.int64(85),
#  'wish guy': np.int64(2375),
#  'guy great': np.int64(683),
#  'great semest': np.int64(664),
#  'goin': np.int64(643),
#  'wonder': np.int64(2432),
#  'phone': np.int64(1188),
#  'batteri': np.int64(114),
#  'wonder phone': np.int64(2436),
#  'went dead': np.int64(2298),
#  'love babe': np.int64(937),
#  'turn': np.int64(2110),
#  'mi': np.int64(1003),
#  'eye': np.int64(497),
#  'otherwis': np.int64(1161),
#  'part': np.int64(1172),
#  'na': np.int64(1069),
#  'tuition': np.int64(2109),
#  'yup': np.int64(2498),
#  'soon': np.int64(1905),
#  'back soon': np.int64(105),
#  'gonna': np.int64(645),
#  'taco': np.int64(1980),
#  'also': np.int64(42),
#  'cbe': np.int64(231),
#  'pay': np.int64(1178),
#  'problem': np.int64(1515),
#  'sch': np.int64(1805),
#  'rem': np.int64(1654),
#  'ok problem': np.int64(1136),
#  'go sch': np.int64(633),
#  'rem correctli': np.int64(1655),
#  'er': np.int64(471),
#  'sure': np.int64(1968),
#  'prop': np.int64(1519),
#  'meant': np.int64(986),
#  'cant': np.int64(216),
#  'join': np.int64(822),
#  'train': np.int64(2090),
#  'role': np.int64(1767),
#  'model': np.int64(1037),
#  'realli': np.int64(1567),
#  'miracl': np.int64(1016),
#  'reason': np.int64(1581),
#  'everyth': np.int64(487),
#  'must': np.int64(1068),
#  'knew': np.int64(848),
#  'look': np.int64(924),
#  'sinc': np.int64(1863),
#  'realli wish': np.int64(1578),
#  'wish day': np.int64(2371),
#  'reason everyth': np.int64(1582),
#  'wish knew': np.int64(2378),
#  'plural': np.int64(1299),
#  'research': np.int64(1724),
#  'plural noun': np.int64(1300),
#  'pl': np.int64(1222),
#  'left': np.int64(888),
#  'silent': np.int64(1859),
#  'night': np.int64(1103),
#  'check': np.int64(245),
#  'til': np.int64(2047),
#  'phone silent': np.int64(1193),
#  'sir': np.int64(1865),
#  'pride': np.int64(1480),
#  'pleasur': np.int64(1290),
#  'tea': np.int64(1989),
#  'shop': np.int64(1849),
#  'contact': np.int64(311),
#  'qatar': np.int64(1539),
#  'rakhesh': np.int64(1545),
#  'indian': np.int64(789),
#  'save': np.int64(1798),
#  'respect': np.int64(1731),
#  'regard': np.int64(1638),
#  'pride pleasur': np.int64(1482),
#  'pleasur meet': np.int64(1291),
#  'pleas send': np.int64(1282),
#  'pl save': np.int64(1236),
#  'respect regard': np.int64(1733),
#  'search': np.int64(1812),
#  'fall': np.int64(503),
#  'bcoz': np.int64(117),
#  'forc': np.int64(557),
#  'smeon': np.int64(1888),
#  'bslvyl': np.int64(173),
#  'dont search': np.int64(414),
#  'search love': np.int64(1814),
#  'love let': np.int64(940),
#  'let love': np.int64(894),
#  'love find': np.int64(939),
#  'find that': np.int64(533),
#  'that call': np.int64(2027),
#  'call fall': np.int64(194),
#  'fall love': np.int64(505),
#  'love bcoz': np.int64(938),
#  'bcoz dont': np.int64(118),
#  'dont forc': np.int64(410),
#  'forc fall': np.int64(558),
#  'fall know': np.int64(504),
#  'know smeon': np.int64(852),
#  'smeon hold': np.int64(1889),
#  'hold bslvyl': np.int64(743),
#  'want ya': np.int64(2201),
#  'love ya': np.int64(941),
#  'plan': np.int64(1250),
#  'lt': np.int64(945),
#  'url': np.int64(2150),
#  'gt': np.int64(667),
#  'tell friend': np.int64(1999),
#  'plan valentin': np.int64(1257),
#  'quit': np.int64(1543),
#  'slowli': np.int64(1881),
#  'hang': np.int64(695),
#  'plan limp': np.int64(1252),
#  'abiola': np.int64(2),
#  'congrat': np.int64(303),
#  'videophon': np.int64(2171),
#  'videochat': np.int64(2169),
#  'play': np.int64(1258),
#  'java': np.int64(814),
#  'game': np.int64(595),
#  'dload': np.int64(403),
#  'polyph': np.int64(1359),
#  'nolin': np.int64(1110),
#  'rentl': np.int64(1688),
#  'bx': np.int64(184),
#  'ip': np.int64(802),
#  'congrat mobil': np.int64(304),
#  'mobil videophon': np.int64(1034),
#  'videophon call': np.int64(2172),
#  'call videochat': np.int64(206),
#  'videochat wid': np.int64(2170),
#  'wid ur': np.int64(2319),
#  'ur mate': np.int64(2142),
#  'mate play': np.int64(972),
#  'play java': np.int64(1261),
#  'java game': np.int64(815),
#  'game dload': np.int64(596),
#  'polyph music': np.int64(1360),
#  'music nolin': np.int64(1066),
#  'nolin rentl': np.int64(1111),
#  'rentl bx': np.int64(1689),
#  'bx ip': np.int64(185),
#  'instead': np.int64(795),
#  'fun': np.int64(592),
#  'someon': np.int64(1898),
#  'test': np.int64(2007),
#  'away': np.int64(100),
#  'town': np.int64(2087),
#  'get away': np.int64(607),
#  'readi': np.int64(1553),
#  'class': np.int64(262),
#  'wish great': np.int64(2374),
#  'day abiola': np.int64(360),
#  'text': np.int64(2008),
#  'pshew': np.int64(1527),
#  'pshew miss': np.int64(1528),
#  'track': np.int64(2089),
#  'yeah sure': np.int64(2486),
#  'coupl minut': np.int64(331),
#  'could': np.int64(327),
#  'seen': np.int64(1820),
#  'recognis': np.int64(1611),
#  'face': np.int64(500),
#  'recognis face': np.int64(1612),
#  'dint': np.int64(396),
#  'nokia': np.int64(1108),
#  'camera': np.int64(212),
#  'ave': np.int64(92),
#  'min': np.int64(1007),
#  'vari': np.int64(2163),
#  'close': np.int64(267),
#  'post': np.int64(1393),
#  'bcm': np.int64(115),
#  'ldn': np.int64(878),
#  'wc': np.int64(2251),
#  'xx': np.int64(2473),
#  'congrat nokia': np.int64(305),
#  'nokia video': np.int64(1109),
#  'video camera': np.int64(2166),
#  'camera phone': np.int64(213),
#  'phone call': np.int64(1189),
#  'call call': np.int64(190),
#  'call cost': np.int64(192),
#  'cost ppm': np.int64(324),
#  'ppm ave': np.int64(1421),
#  'ave call': np.int64(93),
#  'call min': np.int64(199),
#  'min vari': np.int64(1011),
#  'vari mobil': np.int64(2164),
#  'mobil close': np.int64(1028),
#  'close post': np.int64(268),
#  'post bcm': np.int64(1394),
#  'bcm ldn': np.int64(116),
#  'ldn wc': np.int64(879),
#  'wc xx': np.int64(2252),
#  'real': np.int64(1556),
#  'tho': np.int64(2037),
#  'cook': np.int64(317),
#  'real tho': np.int64(1561),
#  'whole electr': np.int64(2311),
#  'ericsson': np.int64(472),
#  'use': np.int64(2154),
#  'consid': np.int64(310),
#  'ok lor': np.int64(1133),
#  'tomorrow': np.int64(2070),
#  'hand': np.int64(692),
#  'prior': np.int64(1491),
#  'pain': np.int64(1166),
#  'di': np.int64(388),
#  'pass': np.int64(1176),
#  'women': np.int64(2429),
#  'pray fate': np.int64(1443),
#  'hold hand': np.int64(744),
#  'love amp': np.int64(936),
#  'prior grief': np.int64(1492),
#  'pl join': np.int64(1231),
#  'amaz': np.int64(46),
#  'rearrang': np.int64(1579),
#  'letter': np.int64(896),
#  'room': np.int64(1768),
#  'moon': np.int64(1046),
#  'recount': np.int64(1616),
#  'woman': np.int64(2425),
#  'plu': np.int64(1295),
#  'twelv': np.int64(2112),
#  'rearrang letter': np.int64(1580),
#  'result lie': np.int64(1750),
#  'recount mother': np.int64(1617),
#  'woman hitler': np.int64(2426),
#  'plu two': np.int64(1298),
#  'plu one': np.int64(1297),
#  'aah': np.int64(0),
#  'lot': np.int64(931),
#  'kind': np.int64(843),
#  'worri': np.int64(2455),
#  'sure get': np.int64(1969),
#  'condit': np.int64(300),
#  'doubl': np.int64(416),
#  'answer': np.int64(57),
#  'better': np.int64(133),
#  'reboot': np.int64(1585),
#  'ym': np.int64(2494),
#  'reboot ym': np.int64(1586),
#  'true': np.int64(2102),
#  'care': np.int64(220),
#  'wil': np.int64(2330),
#  'though': np.int64(2038),
#  'mistak': np.int64(1021),
#  'wil nevr': np.int64(2333),
#  'huh': np.int64(770),
#  'tot': np.int64(2083),
#  'reach': np.int64(1550),
#  'long': np.int64(922),
#  'ago': np.int64(27),
#  'liao': np.int64(897),
#  'leh': np.int64(889),
#  'liao day': np.int64(898),
#  'made': np.int64(959),
#  'weed': np.int64(2261),
#  'torch': np.int64(2081),
#  'bold': np.int64(150),
#  'torch bold': np.int64(2082),
#  'happen dont': np.int64(698),
#  'think': np.int64(2033),
#  'think get': np.int64(2034),
#  'offer': np.int64(1124),
#  'discount': np.int64(399),
#  'voucher': np.int64(2177),
#  'savamob': np.int64(1796),
#  'member': np.int64(992),
#  'unsub': np.int64(2133),
#  'today offer': np.int64(2066),
#  'offer claim': np.int64(1125),
#  'claim ur': np.int64(260),
#  'ur worth': np.int64(2146),
#  'worth discount': np.int64(2457),
#  'discount voucher': np.int64(400),
#  'voucher text': np.int64(2178),
#  'text ye': np.int64(2014),
#  'ye savamob': np.int64(2483),
#  'savamob member': np.int64(1797),
#  'member offer': np.int64(993),
#  'offer mobil': np.int64(1126),
#  'mobil cs': np.int64(1030),
#  'cs sub': np.int64(338),
#  'sub unsub': np.int64(1955),
#  'unsub repli': np.int64(2134),
#  'pleas shelv': np.int64(1283),
#  'name': np.int64(1072),
#  'pl send': np.int64(1237),
#  'what': np.int64(2300),
#  'oh got': np.int64(1130),
#  'wen': np.int64(2293),
#  'id': np.int64(775),
#  'wont': np.int64(2439),
#  'within': np.int64(2393),
#  'give us': np.int64(625),
#  'lt gt': np.int64(947),
#  'gt rs': np.int64(673),
#  'wont allow': np.int64(2441),
#  'come home': np.int64(289),
#  'within day': np.int64(2394),
#  'cup': np.int64(340),
#  'drop': np.int64(427),
#  'finger': np.int64(536),
#  'yoga': np.int64(2496),
#  'basic': np.int64(112),
#  'sleep': np.int64(1876),
#  'sleep good': np.int64(1878),
#  'offici': np.int64(1128),
#  'spider': np.int64(1923),
#  'play offici': np.int64(1263),
#  'ur mobil': np.int64(2144),
#  'game send': np.int64(597),
#  'send free': np.int64(1828),
#  'darren': np.int64(355),
#  'oso': np.int64(1160),
#  'tmr': np.int64(2058),
#  'haf': np.int64(687),
#  'lect': np.int64(887),
#  'posh': np.int64(1387),
#  'bird': np.int64(138),
#  'user': np.int64(2155),
#  'address': np.int64(18),
#  'posh bird': np.int64(1388),
#  'doc': np.int64(404),
#  'prescrib': np.int64(1458),
#  'caus': np.int64(230),
#  'med': np.int64(987),
#  'bring': np.int64(169),
#  'fast': np.int64(512),
#  'prescrib morphin': np.int64(1459),
#  'convey': np.int64(315),
#  'birthday': np.int64(139),
#  'pl favour': np.int64(1228),
#  'pl convey': np.int64(1225),
#  'wish nimya': np.int64(2380),
#  'pl today': np.int64(1239),
#  'yo': np.int64(2495),
#  'carlo': np.int64(223),
#  'excel': np.int64(491),
#  'moan': np.int64(1023),
#  'mth': np.int64(1061),
#  'half': np.int64(690),
#  'price': np.int64(1475),
#  'orang': np.int64(1155),
#  'rental': np.int64(1683),
#  'updat': np.int64(2136),
#  'half price': np.int64(691),
#  'price orang': np.int64(1479),
#  'line rental': np.int64(911),
#  'rental latest': np.int64(1685),
#  'free phone': np.int64(573),
#  'mail': np.int64(960),
#  'inform': np.int64(794),
#  'account': np.int64(10),
#  'rent': np.int64(1678),
#  'discuss': np.int64(401),
#  'hous': np.int64(764),
#  'anoth': np.int64(56),
#  'onlin': np.int64(1144),
#  'around': np.int64(75),
#  'said would': np.int64(1790),
#  'rent discuss': np.int64(1680),
#  'rent anoth': np.int64(1679),
#  'place check': np.int64(1243),
#  'place around': np.int64(1241),
#  'old': np.int64(1139),
#  'orchard': np.int64(1156),
#  'mr': np.int64(1054),
#  'gay': np.int64(599),
#  'finish': np.int64(537),
#  'hey mr': np.int64(724),
#  'way': np.int64(2235),
#  'detail': np.int64(387),
#  'find way': np.int64(534),
#  'way includ': np.int64(2242),
#  'cool': np.int64(318),
#  'cool text': np.int64(319),
#  'behav': np.int64(123),
#  'behav like': np.int64(124),
#  'aight text': np.int64(30),
#  'depend': np.int64(385),
#  'singl': np.int64(1864),
#  'area': np.int64(72),
#  'per': np.int64(1182),
#  'free msg': np.int64(572),
#  'real peopl': np.int64(1560),
#  'chat send': np.int64(244),
#  'send chat': np.int64(1827),
#  'anyth': np.int64(60),
#  'possess': np.int64(1391),
#  'especi': np.int64(473),
#  'possess especi': np.int64(1392),
#  'congratul': np.int64(307),
#  'entri': np.int64(466),
#  'wkli': np.int64(2417),
#  'tnc': np.int64(2059),
#  'age': np.int64(25),
#  'ur award': np.int64(2138),
#  'free entri': np.int64(569),
#  'entri wkli': np.int64(470),
#  'wkli draw': np.int64(2419),
#  'music tnc': np.int64(1067),
#  'ppmx age': np.int64(1424),
#  'like lt': np.int64(907),
#  ...}

# %%
type(y)
# Out:
# numpy.ndarray

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
spam_tfidf_model = MultinomialNB().fit(X_train,y_train)

# %%
y_pred=spam_tfidf_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,classification_report

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7955156950672646

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.26      0.25      0.25       156
#         True       0.88      0.88      0.88       959
#
#     accuracy                           0.80      1115
#    macro avg       0.57      0.57      0.57      1115
# weighted avg       0.79      0.80      0.79      1115
