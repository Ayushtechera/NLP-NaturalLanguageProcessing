# %% [markdown]
# # What we gonna do in this notebook
# 1. BOW
# 3. Machine learning Algorithm

# %%
import pandas as pd

# %%
messages = pd.read_csv('../SpamClassifier\smsSpamcollection\SMSSpamCollection',
                        sep='\t',
                        names=['label','message'])

# %%
messages
# Out:
#      label                                            message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham               Will ü b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %% [markdown]
# ### Data Cleaning And preprocessing

# %%
import re 
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Ayush
# [nltk_data]     Kashyap\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
corpus = []
for i in range(0,len(messages)):
    review=re.sub('[^a-zA-Z]',' ',messages['message'][i])
    review=review.lower()
    review=review.split()
    review=[ps.stem(word) for word in review if not word in stopwords.words('english')]
    review=' '.join(review)
    corpus.append(review)

# %%
y = pd.get_dummies(messages['label'])
y=y.iloc[:,0].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(corpus,y,test_size=0.20)

# %% [markdown]
# ## Creating Bag Of Words

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=2500,ngram_range=(1,2))

# %% [markdown]
# ### Input Feature

# %%
# Independent Features
X_train= cv.fit_transform(X_train)
X_test = cv.transform(X_test)

# %%
cv.vocabulary_
# Out:
# {'dint': np.int64(534),
#  'slept': np.int64(1907),
#  'afternoon': np.int64(30),
#  'talk': np.int64(2047),
#  'tone': np.int64(2152),
#  'club': np.int64(366),
#  'sub': np.int64(2011),
#  'expir': np.int64(642),
#  'repli': np.int64(1724),
#  'mono': np.int64(1354),
#  'poli': np.int64(1607),
#  'weekli': np.int64(2371),
#  'per': np.int64(1541),
#  'week': np.int64(2362),
#  'txt': np.int64(2201),
#  'stop': np.int64(1988),
#  'msg': np.int64(1373),
#  'free': np.int64(713),
#  'per week': np.int64(1547),
#  'week txt': np.int64(2368),
#  'txt stop': np.int64(2213),
#  'stop stop': np.int64(1994),
#  'msg free': np.int64(1375),
#  'decid': np.int64(503),
#  'go': np.int64(802),
#  'way': np.int64(2349),
#  'im': np.int64(1010),
#  'complet': np.int64(401),
#  'broke': np.int64(215),
#  'got': np.int64(845),
#  'bout': np.int64(202),
#  'mrw': np.int64(1372),
#  'love': np.int64(1205),
#  'dad': np.int64(476),
#  'fone': np.int64(697),
#  'credit': np.int64(450),
#  'hi': np.int64(933),
#  'pete': np.int64(1551),
#  'ive': np.int64(1048),
#  'bin': np.int64(172),
#  'recent': np.int64(1701),
#  'hav': np.int64(914),
#  'sum': np.int64(2020),
#  'left': np.int64(1144),
#  'bill': np.int64(171),
#  'said': np.int64(1778),
#  'ur': np.int64(2245),
#  'rent': np.int64(1721),
#  'mayb': np.int64(1278),
#  'interest': np.int64(1034),
#  'around': np.int64(92),
#  'told': np.int64(2148),
#  'number': np.int64(1457),
#  'sir': np.int64(1887),
#  'use': np.int64(2274),
#  'dear': np.int64(500),
#  'peopl': np.int64(1539),
#  'mu': np.int64(1381),
#  'ok': np.int64(1476),
#  'ill': np.int64(1009),
#  'send': np.int64(1829),
#  'lt': np.int64(1217),
#  'decim': np.int64(504),
#  'gt': np.int64(865),
#  'lt decim': np.int64(1218),
#  'decim gt': np.int64(505),
#  'hot': np.int64(972),
#  'live': np.int64(1176),
#  'fantasi': np.int64(654),
#  'call': np.int64(242),
#  'min': np.int64(1305),
#  'ntt': np.int64(1454),
#  'ltd': np.int64(1221),
#  'po': np.int64(1598),
#  'box': np.int64(203),
#  'croydon': np.int64(452),
#  'cr': np.int64(444),
#  'wb': np.int64(2351),
#  'nation': np.int64(1397),
#  'rate': np.int64(1675),
#  'hot live': np.int64(973),
#  'live fantasi': np.int64(1177),
#  'fantasi call': np.int64(655),
#  'call per': np.int64(260),
#  'per min': np.int64(1543),
#  'min ntt': np.int64(1307),
#  'ntt ltd': np.int64(1455),
#  'ltd po': np.int64(1222),
#  'po box': np.int64(1599),
#  'box croydon': np.int64(204),
#  'croydon cr': np.int64(453),
#  'cr wb': np.int64(445),
#  'wb nation': np.int64(2352),
#  'nation rate': np.int64(1398),
#  'rate call': np.int64(1677),
#  'darlin': np.int64(482),
#  'london': np.int64(1190),
#  'anoth': np.int64(64),
#  'big': np.int64(170),
#  'realli': np.int64(1692),
#  'miss': np.int64(1320),
#  'xxx': np.int64(2462),
#  'hi darlin': np.int64(935),
#  'realli miss': np.int64(1693),
#  'hey': np.int64(928),
#  'da': np.int64(472),
#  'cool': np.int64(427),
#  'spk': np.int64(1960),
#  'mean': np.int64(1280),
#  'could': np.int64(437),
#  'keep': np.int64(1076),
#  'word': np.int64(2423),
#  'life': np.int64(1158),
#  'lot': np.int64(1203),
#  'world': np.int64(2428),
#  'friend': np.int64(733),
#  'ge': np.int64(762),
#  'person': np.int64(1549),
#  'stori': np.int64(1999),
#  'person stori': np.int64(1550),
#  'still': np.int64(1982),
#  'chanc': np.int64(321),
#  'search': np.int64(1806),
#  'hard': np.int64(911),
#  'get': np.int64(768),
#  'let': np.int64(1151),
#  'tri': np.int64(2177),
#  'babe': np.int64(129),
#  'goe': np.int64(823),
#  'day': np.int64(487),
#  'think': np.int64(2099),
#  'kiss': np.int64(1091),
#  'across': np.int64(12),
#  'sea': np.int64(1805),
#  'goe day': np.int64(824),
#  'kiss across': np.int64(1092),
#  'across sea': np.int64(13),
#  'tel': np.int64(2063),
#  'hmmm': np.int64(946),
#  'thk': np.int64(2106),
#  'sure': np.int64(2032),
#  'time': np.int64(2124),
#  'hop': np.int64(961),
#  'ard': np.int64(86),
#  'ya': np.int64(2466),
#  'abt': np.int64(3),
#  'muz': np.int64(1392),
#  'discuss': np.int64(540),
#  'liao': np.int64(1155),
#  'watch': np.int64(2345),
#  'hous': np.int64(976),
#  'whole': np.int64(2391),
#  'thing': np.int64(2098),
#  'even': np.int64(620),
#  'especi': np.int64(614),
#  'want': np.int64(2329),
#  'ask': np.int64(98),
#  'wait': np.int64(2315),
#  'finish': np.int64(686),
#  'lect': np.int64(1142),
#  'co': np.int64(368),
#  'hour': np.int64(975),
#  'anyway': np.int64(75),
#  'happen': np.int64(904),
#  'cell': np.int64(318),
#  'good': np.int64(830),
#  'care': np.int64(299),
#  'give': np.int64(794),
#  'tomorrow': np.int64(2150),
#  'give call': np.int64(795),
#  'call tomorrow': np.int64(268),
#  'lor': np.int64(1199),
#  'messag': np.int64(1296),
#  'aathi': np.int64(0),
#  'love lot': np.int64(1209),
#  'anybodi': np.int64(67),
#  'thought': np.int64(2110),
#  'alex': np.int64(46),
#  'fine': np.int64(684),
#  'aint': np.int64(40),
#  'much': np.int64(1382),
#  'tho': np.int64(2108),
#  'saw': np.int64(1792),
#  'movi': np.int64(1366),
#  'yest': np.int64(2484),
#  'quit': np.int64(1663),
#  'funni': np.int64(748),
#  'town': np.int64(2170),
#  'xx': np.int64(2461),
#  'forgot': np.int64(704),
#  'tell': np.int64(2064),
#  'phone': np.int64(1553),
#  'late': np.int64(1116),
#  'lar': np.int64(1110),
#  'wun': np.int64(2449),
#  'clair': np.int64(356),
#  'alon': np.int64(49),
#  'wanna': np.int64(2328),
#  'cum': np.int64(460),
#  'nite': np.int64(1431),
#  'chat': np.int64(329),
#  'hope': np.int64(962),
#  'luv': np.int64(1230),
#  'wa': np.int64(2314),
#  'pleas': np.int64(1585),
#  'immedi': np.int64(1014),
#  'urgent': np.int64(2264),
#  'pleas call': np.int64(1586),
#  'call immedi': np.int64(252),
#  'immedi urgent': np.int64(1015),
#  'urgent messag': np.int64(2266),
#  'messag wait': np.int64(1297),
#  'boy': np.int64(206),
#  'gal': np.int64(752),
#  'bt': np.int64(219),
#  'didnt': np.int64(523),
#  'mind': np.int64(1311),
#  'frnd': np.int64(740),
#  'speed': np.int64(1957),
#  'toward': np.int64(2169),
#  'hit': np.int64(940),
#  'girl': np.int64(791),
#  'ran': np.int64(1672),
#  'like': np.int64(1163),
#  'hell': np.int64(923),
#  'save': np.int64(1791),
#  'hw': np.int64(995),
#  'run': np.int64(1771),
#  'fast': np.int64(659),
#  'boost': np.int64(195),
#  'secret': np.int64(1811),
#  'energi': np.int64(600),
#  'shout': np.int64(1867),
#  'drink': np.int64(565),
#  'moral': np.int64(1359),
#  'hv': np.int64(994),
#  'gud': np.int64(879),
#  'ni': np.int64(1424),
#  'bt didnt': np.int64(220),
#  'free msg': np.int64(721),
#  'gud ni': np.int64(882),
#  'cant': np.int64(291),
#  'gotta': np.int64(852),
#  'mum': np.int64(1383),
#  'yup': np.int64(2497),
#  'work': np.int64(2424),
#  'probabl': np.int64(1647),
#  'eat': np.int64(583),
#  'today': np.int64(2141),
#  'gonna': np.int64(828),
#  'pop': np.int64(1612),
#  'weekend': np.int64(2369),
#  'think gonna': np.int64(2103),
#  'glad': np.int64(797),
#  'follow': np.int64(696),
#  'dream': np.int64(564),
#  'forget': np.int64(703),
#  'own': np.int64(1515),
#  'privat': np.int64(1639),
#  'alway': np.int64(54),
#  'passion': np.int64(1532),
#  'good boy': np.int64(832),
#  'passion kiss': np.int64(1533),
#  'welcom': np.int64(2375),
#  'uk': np.int64(2226),
#  'mobil': np.int64(1334),
#  'date': np.int64(485),
#  'futur': np.int64(749),
#  'daili': np.int64(478),
#  'cancel': np.int64(288),
#  'free call': np.int64(715),
#  'send go': np.int64(1832),
#  'haha': np.int64(894),
#  'first': np.int64(687),
#  'sorri': np.int64(1940),
#  'later': np.int64(1117),
#  'sorri call': np.int64(1941),
#  'call later': np.int64(255),
#  'found': np.int64(710),
#  'di': np.int64(521),
#  'one': np.int64(1490),
#  'look': np.int64(1195),
#  'normal': np.int64(1448),
#  'cost': np.int64(432),
#  'sale': np.int64(1784),
#  'cover': np.int64(441),
#  'oso': np.int64(1509),
#  'half': np.int64(897),
#  'page': np.int64(1520),
#  'gift': np.int64(788),
#  'someth': np.int64(1932),
#  'tri get': np.int64(2181),
#  'auction': np.int64(113),
#  'round': np.int64(1763),
#  'bid': np.int64(169),
#  'next': np.int64(1422),
#  'luck': np.int64(1223),
#  'good luck': np.int64(836),
#  'thank': np.int64(2090),
#  'video': np.int64(2291),
#  'charg': np.int64(325),
#  'better': np.int64(167),
#  'rington': np.int64(1751),
#  'gr': np.int64(855),
#  'new': np.int64(1416),
#  'direct': np.int64(535),
#  'everi': np.int64(623),
#  'everi week': np.int64(626),
#  'move': np.int64(1365),
#  'lt gt': np.int64(1219),
#  'wot': np.int64(2435),
#  'award': np.int64(121),
#  'prize': np.int64(1641),
#  'guarante': np.int64(875),
#  'land': np.int64(1102),
#  'line': np.int64(1167),
#  'claim': np.int64(346),
#  'valid': np.int64(2282),
#  'hr': np.int64(983),
#  'urgent mobil': np.int64(2267),
#  'mobil number': np.int64(1341),
#  'number award': np.int64(1458),
#  'award prize': np.int64(125),
#  'prize guarante': np.int64(1644),
#  'guarante call': np.int64(876),
#  'call land': np.int64(253),
#  'land line': np.int64(1103),
#  'line claim': np.int64(1168),
#  'claim valid': np.int64(353),
#  'valid hr': np.int64(2284),
#  'say': np.int64(1793),
#  'slowli': np.int64(1911),
#  'god': np.int64(821),
#  'amp': np.int64(57),
#  'need': np.int64(1405),
#  'clean': np.int64(358),
#  'heart': np.int64(919),
#  'blood': np.int64(182),
#  'ten': np.int64(2067),
#  'special': np.int64(1952),
#  'miracl': np.int64(1318),
#  'pl': np.int64(1572),
#  'say slowli': np.int64(1796),
#  'slowli god': np.int64(1912),
#  'god love': np.int64(822),
#  'love amp': np.int64(1206),
#  'amp need': np.int64(59),
#  'need clean': np.int64(1406),
#  'clean heart': np.int64(359),
#  'heart blood': np.int64(920),
#  'blood send': np.int64(183),
#  'send ten': np.int64(1837),
#  'ten special': np.int64(2068),
#  'special peopl': np.int64(1955),
#  'peopl amp': np.int64(1540),
#  'amp miracl': np.int64(58),
#  'miracl tomorrow': np.int64(1319),
#  'tomorrow pl': np.int64(2151),
#  'pl pl': np.int64(1576),
#  'huh': np.int64(988),
#  'park': np.int64(1526),
#  'ah': np.int64(35),
#  'tt': np.int64(2192),
#  'best': np.int64(165),
#  'choic': np.int64(341),
#  'den': np.int64(516),
#  'juz': np.int64(1071),
#  'take': np.int64(2044),
#  'believ': np.int64(162),
#  'true': np.int64(2185),
#  'learn': np.int64(1138),
#  'truli': np.int64(2186),
#  'amaz': np.int64(55),
#  'blow': np.int64(186),
#  'txt repli': np.int64(2212),
#  'us': np.int64(2273),
#  'back': np.int64(132),
#  'loan': np.int64(1181),
#  'give us': np.int64(796),
#  'mani': np.int64(1256),
#  'buy': np.int64(232),
#  'wast': np.int64(2340),
#  'adult': np.int64(25),
#  'content': np.int64(422),
#  'ad': np.int64(18),
#  'contact': np.int64(414),
#  'list': np.int64(1172),
#  'www': np.int64(2450),
#  'fullonsm': np.int64(745),
#  'com': np.int64(386),
#  'great': np.int64(858),
#  'place': np.int64(1578),
#  'sm': np.int64(1913),
#  'visit': np.int64(2302),
#  'fullonsm com': np.int64(746),
#  'send free': np.int64(1831),
#  'group': np.int64(864),
#  'mail': np.int64(1243),
#  'check': np.int64(333),
#  'hmm': np.int64(945),
#  'bad': np.int64(135),
#  'news': np.int64(1421),
#  'boss': np.int64(197),
#  'know': np.int64(1094),
#  'well': np.int64(2376),
#  'know well': np.int64(1097),
#  'readi': np.int64(1687),
#  'summer': np.int64(2021),
#  'select': np.int64(1824),
#  'worth': np.int64(2433),
#  'saturday': np.int64(1788),
#  'co uk': np.int64(370),
#  'class': np.int64(357),
#  'water': np.int64(2347),
#  'make': np.int64(1248),
#  'challeng': np.int64(320),
#  'sinc': np.int64(1882),
#  'boston': np.int64(199),
#  'statement': np.int64(1975),
#  'lol': np.int64(1189),
#  'chang': np.int64(323),
#  'realiz': np.int64(1691),
#  'nyc': np.int64(1463),
#  'ye': np.int64(2473),
#  'princess': np.int64(1636),
#  'catch': np.int64(311),
#  'strong': np.int64(2004),
#  'hand': np.int64(900),
#  'ye princess': np.int64(2475),
#  'princess want': np.int64(1637),
#  'busi': np.int64(231),
#  'come': np.int64(389),
#  'point': np.int64(1605),
#  'figur': np.int64(673),
#  'feel': np.int64(666),
#  'money': np.int64(1353),
#  'dinner': np.int64(533),
#  'never': np.int64(1415),
#  'dont': np.int64(551),
#  'wil': np.int64(2397),
#  'hurt': np.int64(993),
#  'wen': np.int64(2379),
#  'dont miss': np.int64(553),
#  'take care': np.int64(2045),
#  'gym': np.int64(890),
#  'excus': np.int64(637),
#  'lazi': np.int64(1130),
#  'final': np.int64(677),
#  'hear': np.int64(917),
#  'laptop': np.int64(1109),
#  'case': np.int64(304),
#  'forc': np.int64(701),
#  'hungri': np.int64(990),
#  'suck': np.int64(2015),
#  'mark': np.int64(1261),
#  'worri': np.int64(2431),
#  'sick': np.int64(1874),
#  'turn': np.int64(2196),
#  'pizza': np.int64(1571),
#  'yep': np.int64(2483),
#  'pretti': np.int64(1633),
#  'yo': np.int64(2489),
#  'yo yo': np.int64(2490),
#  'sweet': np.int64(2038),
#  'reach': np.int64(1683),
#  'home': np.int64(958),
#  'reach home': np.int64(1685),
#  'admir': np.int64(22),
#  'find': np.int64(679),
#  'reveal': np.int64(1743),
#  'secret admir': np.int64(1812),
#  'admir look': np.int64(23),
#  'look make': np.int64(1197),
#  'make contact': np.int64(1249),
#  'contact find': np.int64(418),
#  'find reveal': np.int64(682),
#  'reveal think': np.int64(1744),
#  'think ur': np.int64(2104),
#  'ur special': np.int64(2260),
#  'special call': np.int64(1954),
#  'got lt': np.int64(849),
#  'goodmorn': np.int64(841),
#  'gt min': np.int64(869),
#  'usual': np.int64(2278),
#  'iam': np.int64(996),
#  'happi': np.int64(905),
#  'aight': np.int64(38),
#  'close': np.int64(363),
#  'landlin': np.int64(1105),
#  'cash': np.int64(305),
#  'luxuri': np.int64(1232),
#  'island': np.int64(1046),
#  'holiday': np.int64(953),
#  'await': np.int64(118),
#  'collect': np.int64(380),
#  'cs': np.int64(454),
#  'sae': np.int64(1774),
#  'xy': np.int64(2465),
#  'ppm': np.int64(1622),
#  'urgent pleas': np.int64(2268),
#  'call landlin': np.int64(254),
#  'holiday await': np.int64(954),
#  'await collect': np.int64(119),
#  'would': np.int64(2436),
#  'appreci': np.int64(82),
#  'someon': np.int64(1930),
#  'wan': np.int64(2323),
#  'anyth': np.int64(70),
#  'john': np.int64(1062),
#  'feel like': np.int64(668),
#  'al': np.int64(45),
#  'share': np.int64(1859),
#  'offer': np.int64(1466),
#  'join': np.int64(1063),
#  'allah': np.int64(47),
#  'meet': np.int64(1285),
#  'sometim': np.int64(1935),
#  'rakhesh': np.int64(1670),
#  'india': np.int64(1024),
#  'good even': np.int64(834),
#  'wnt': np.int64(2418),
#  'car': np.int64(297),
#  'vri': np.int64(2313),
#  'that': np.int64(2095),
#  'prob': np.int64(1646),
#  'knw': np.int64(1098),
#  'vl': np.int64(2304),
#  'kano': np.int64(1073),
#  'enjoy': np.int64(603),
#  'wit': np.int64(2410),
#  'famili': np.int64(652),
#  'st': np.int64(1965),
#  'salari': np.int64(1783),
#  'stay': np.int64(1978),
#  'hug': np.int64(987),
#  'lmao': np.int64(1179),
#  'wont': np.int64(2422),
#  'hair': np.int64(896),
#  'anymor': np.int64(68),
#  'havent': np.int64(915),
#  'plan': np.int64(1579),
#  'alreadi': np.int64(50),
#  'show': np.int64(1868),
#  'account': np.int64(10),
#  'un': np.int64(2229),
#  'redeem': np.int64(1704),
#  'identifi': np.int64(1003),
#  'code': np.int64(371),
#  'privat account': np.int64(1640),
#  'account statement': np.int64(11),
#  'statement show': np.int64(1976),
#  'show un': np.int64(1870),
#  'un redeem': np.int64(2230),
#  'redeem point': np.int64(1705),
#  'point call': np.int64(1606),
#  'call identifi': np.int64(251),
#  'identifi code': np.int64(1004),
#  'code expir': np.int64(372),
#  'receiv': np.int64(1698),
#  'time get': np.int64(2127),
#  'tat': np.int64(2050),
#  'wat': np.int64(2341),
#  'wat time': np.int64(2343),
#  'time wan': np.int64(2131),
#  'wan come': np.int64(2324),
#  'link': np.int64(1170),
#  'game': np.int64(753),
#  'crazi': np.int64(448),
#  'cuz': np.int64(471),
#  'studi': np.int64(2006),
#  'earlier': np.int64(579),
#  'station': np.int64(1977),
#  'came': np.int64(279),
#  'ago': np.int64(34),
#  'job': np.int64(1061),
#  'actual': np.int64(17),
#  'delet': np.int64(511),
#  'old': np.int64(1487),
#  'websit': np.int64(2358),
#  'pray': np.int64(1626),
#  'remov': np.int64(1720),
#  'pain': np.int64(1521),
#  'maintain': np.int64(1245),
#  'stuff': np.int64(2007),
#  'good day': np.int64(833),
#  'definit': np.int64(508),
#  'modul': np.int64(1348),
#  'izzit': np.int64(1050),
#  'mm': np.int64(1327),
#  'umma': np.int64(2228),
#  'also': np.int64(53),
#  'play': np.int64(1581),
#  'togeth': np.int64(2147),
#  'load': np.int64(1180),
#  'thank god': np.int64(2091),
#  'noe': np.int64(1433),
#  'dat': np.int64(484),
#  'sell': np.int64(1827),
#  'oh': np.int64(1472),
#  'camera': np.int64(282),
#  'pic': np.int64(1559),
#  'sent': np.int64(1841),
#  'porn': np.int64(1613),
#  'text': np.int64(2076),
#  'wc': np.int64(2353),
#  'per day': np.int64(1542),
#  'stop text': np.int64(1995),
#  'wc xx': np.int64(2354),
#  'england': np.int64(601),
#  'gbp': np.int64(760),
#  'network': np.int64(1412),
#  'oper': np.int64(1498),
#  'appli': np.int64(81),
#  'tone repli': np.int64(2155),
#  'rate appli': np.int64(1676),
#  'internet': np.int64(1035),
#  'eh': np.int64(589),
#  'request': np.int64(1733),
#  'set': np.int64(1850),
#  'callertun': np.int64(274),
#  'caller': np.int64(271),
#  'press': np.int64(1631),
#  'copi': np.int64(429),
#  'per request': np.int64(1546),
#  'set callertun': np.int64(1851),
#  'callertun caller': np.int64(275),
#  'caller press': np.int64(272),
#  'press copi': np.int64(1632),
#  'copi friend': np.int64(430),
#  'friend callertun': np.int64(734),
#  'tv': np.int64(2197),
#  'avail': np.int64(116),
#  'work place': np.int64(2426),
#  'horni': np.int64(968),
#  'local': np.int64(1183),
#  'netcollex': np.int64(1411),
#  'end': np.int64(597),
#  'per msg': np.int64(1545),
#  'repli stop': np.int64(1728),
#  'stop end': np.int64(1990),
#  'wan go': np.int64(2325),
#  'trip': np.int64(2183),
#  'wonder': np.int64(2421),
#  'everyon': np.int64(628),
#  'befor': np.int64(158),
#  'greet': np.int64(862),
#  'kind': np.int64(1088),
#  'affair': np.int64(27),
#  'cheer': np.int64(334),
#  'logo': np.int64(1187),
#  'question': np.int64(1661),
#  'info': np.int64(1026),
#  'sky': np.int64(1899),
#  'dark': np.int64(481),
#  'rain': np.int64(1668),
#  'rite': np.int64(1753),
#  'hee': np.int64(922),
#  'boo': np.int64(193),
#  'littl': np.int64(1175),
#  'bore': np.int64(196),
#  'back home': np.int64(134),
#  'lei': np.int64(1146),
#  'tc': np.int64(2052),
#  'practic': np.int64(1625),
#  'cant come': np.int64(292),
#  'mate': np.int64(1267),
#  'went': np.int64(2381),
#  'longer': np.int64(1194),
#  'possibl': np.int64(1615),
#  'beauti': np.int64(152),
#  'may': np.int64(1277),
#  'three': np.int64(2111),
#  'christma': np.int64(343),
#  'merri': np.int64(1295),
#  'idiot': np.int64(1005),
#  'competit': np.int64(400),
#  'knew': np.int64(1093),
#  'two': np.int64(2200),
#  'becom': np.int64(153),
#  'forev': np.int64(702),
#  'one day': np.int64(1491),
#  'alright': np.int64(51),
#  'doin': np.int64(548),
#  'wk': np.int64(2415),
#  'hook': np.int64(960),
#  'sn': np.int64(1921),
#  'doc': np.int64(544),
#  'caus': np.int64(312),
#  'med': np.int64(1282),
#  'enough': np.int64(604),
#  'mom': np.int64(1349),
#  'bring': np.int64(213),
#  'kick': np.int64(1082),
#  'slide': np.int64(1908),
#  'entri': np.int64(609),
#  'comp': np.int64(397),
#  'win': np.int64(2398),
#  'ipod': np.int64(1042),
#  'pod': np.int64(1604),
#  'std': np.int64(1979),
#  'detail': np.int64(519),
#  'entri weekli': np.int64(610),
#  'weekli comp': np.int64(2372),
#  'comp chanc': np.int64(398),
#  'chanc win': np.int64(322),
#  'txt pod': np.int64(2210),
#  'get entri': np.int64(771),
#  'std txt': np.int64(1980),
#  'txt rate': np.int64(2211),
#  'flat': np.int64(693),
#  'congrat': np.int64(409),
#  'year': np.int64(2481),
#  'cinema': np.int64(345),
#  'pass': np.int64(1531),
#  'etc': np.int64(616),
#  'bx': np.int64(233),
#  'ip': np.int64(1040),
#  'pm': np.int64(1594),
#  'etc free': np.int64(617),
#  'bx ip': np.int64(234),
#  'ip pm': np.int64(1041),
#  'freemsg': np.int64(727),
#  'record': np.int64(1702),
#  'entitl': np.int64(607),
#  'pound': np.int64(1618),
#  'accid': np.int64(8),
#  'opt': np.int64(1501),
#  'claim free': np.int64(350),
#  'free repli': np.int64(723),
#  'repli ye': np.int64(1729),
#  'text stop': np.int64(2082),
#  'pick': np.int64(1561),
#  'taunton': np.int64(2051),
#  'want come': np.int64(2330),
#  'voic': np.int64(2308),
#  'hol': np.int64(949),
#  'oki': np.int64(1486),
#  'scare': np.int64(1797),
#  'fat': np.int64(660),
#  'dun': np.int64(571),
#  'dun wan': np.int64(574),
#  'goodnight': np.int64(842),
#  'fix': np.int64(690),
#  'wake': np.int64(2320),
#  'night': np.int64(1428),
#  'sleep': np.int64(1903),
#  'oh ok': np.int64(1474),
#  'good night': np.int64(838),
#  'type': np.int64(2221),
#  'sing': np.int64(1883),
#  'mine': np.int64(1313),
#  'fr': np.int64(711),
#  'china': np.int64(339),
#  'asap': np.int64(97),
#  'ok take': np.int64(1484),
#  'unlimit': np.int64(2236),
#  'access': np.int64(7),
#  'get free': np.int64(772),
#  'law': np.int64(1129),
#  'friendship': np.int64(738),
#  'ur friend': np.int64(2250),
#  'gud night': np.int64(883),
#  'issu': np.int64(1047),
#  'clock': np.int64(362),
#  'lip': np.int64(1171),
#  'brother': np.int64(216),
#  'role': np.int64(1757),
#  'model': np.int64(1347),
#  'leav': np.int64(1140),
#  'crave': np.int64(447),
#  'need crave': np.int64(1407),
#  'remind': np.int64(1719),
#  'dead': np.int64(498),
#  'come back': np.int64(390),
#  'activ': np.int64(16),
#  'full': np.int64(744),
#  'version': np.int64(2288),
#  'guy': np.int64(888),
#  'area': np.int64(88),
#  'name': np.int64(1396),
#  'wait call': np.int64(2316),
#  'friday': np.int64(732),
#  'monday': np.int64(1352),
#  'mood': np.int64(1356),
#  'surpris': np.int64(2035),
#  'guess': np.int64(885),
#  'right': np.int64(1748),
#  'okay': np.int64(1485),
#  'uncl': np.int64(2232),
#  'nigeria': np.int64(1427),
#  'dollar': np.int64(549),
#  'pay': np.int64(1536),
#  'expect': np.int64(639),
#  'let know': np.int64(1153),
#  'gt dollar': np.int64(866),
#  'someth like': np.int64(1933),
#  'singl': np.int64(1884),
#  'nyt': np.int64(1464),
#  'anyth ur': np.int64(72),
#  'ur best': np.int64(2247),
#  'best life': np.int64(166),
#  'gud nyt': np.int64(884),
#  'noon': np.int64(1444),
#  'sorri da': np.int64(1942),
#  'sad': np.int64(1772),
#  'ju': np.int64(1069),
#  'walk': np.int64(2321),
#  'wid': np.int64(2392),
#  'promis': np.int64(1651),
#  'smile': np.int64(1917),
#  'ur smile': np.int64(2259),
#  'custom': np.int64(467),
#  'loyalti': np.int64(1215),
#  'nokia': np.int64(1434),
#  'txtauction': np.int64(2215),
#  'start': np.int64(1973),
#  'mtmsg': np.int64(1380),
#  'offer new': np.int64(1468),
#  'new nokia': np.int64(1418),
#  'nokia mobil': np.int64(1437),
#  'txt word': np.int64(2214),
#  'unsold': np.int64(2238),
#  'import': np.int64(1016),
#  'servic': np.int64(1846),
#  'announc': np.int64(63),
#  'freephon': np.int64(728),
#  'custom servic': np.int64(468),
#  'servic announc': np.int64(1847),
#  'might': np.int64(1301),
#  'might come': np.int64(1302),
#  'lemm': np.int64(1147),
#  'lemm know': np.int64(1148),
#  'yar': np.int64(2470),
#  'yar lor': np.int64(2471),
#  'plenti': np.int64(1590),
#  'music': np.int64(1388),
#  'voucher': np.int64(2311),
#  'draw': np.int64(560),
#  'tsc': np.int64(2191),
#  'age': np.int64(33),
#  'gift voucher': np.int64(790),
#  'week start': np.int64(2367),
#  'lunch': np.int64(1227),
#  'wif': np.int64(2394),
#  'aft': np.int64(29),
#  'str': np.int64(2001),
#  'orchard': np.int64(1505),
#  'go lunch': np.int64(813),
#  'how': np.int64(978),
#  'honey': np.int64(959),
#  'ave': np.int64(117),
#  'de': np.int64(497),
#  'accept': np.int64(6),
#  'moment': np.int64(1350),
#  'th': np.int64(2086),
#  'month': np.int64(1355),
#  'ws': np.int64(2447),
#  'gt th': np.int64(872),
#  'part': np.int64(1527),
#  'morn': np.int64(1360),
#  'happi day': np.int64(907),
#  'rememb': np.int64(1718),
#  'must': np.int64(1391),
#  'get back': np.int64(769),
#  'convey': np.int64(424),
#  'birthday': np.int64(173),
#  'wish': np.int64(2405),
#  'nimya': np.int64(1429),
#  'pl convey': np.int64(1574),
#  'convey birthday': np.int64(425),
#  'birthday wish': np.int64(174),
#  'wish nimya': np.int64(2408),
#  'nimya pl': np.int64(1430),
#  'today birthday': np.int64(2142),
#  'hostel': np.int64(971),
#  'score': np.int64(1801),
#  'school': np.int64(1800),
#  'research': np.int64(1735),
#  'joke': np.int64(1064),
#  'less': np.int64(1149),
#  'expens': np.int64(640),
#  'hey babe': np.int64(929),
#  'smth': np.int64(1920),
#  'arriv': np.int64(95),
#  'soon': np.int64(1939),
#  'ard smth': np.int64(87),
#  'like dat': np.int64(1164),
#  'ar': np.int64(84),
#  'roger': np.int64(1756),
#  'download': np.int64(559),
#  'choos': np.int64(342),
#  'yr': np.int64(2493),
#  'shower': np.int64(1871),
#  'yeah': np.int64(2478),
#  'done': np.int64(550),
#  'yeah leav': np.int64(2480),
#  'rule': np.int64(1770),
#  'qualiti': np.int64(1660),
#  'miss call': np.int64(1323),
#  'without': np.int64(2413),
#  'anoth day': np.int64(65),
#  'dare': np.int64(480),
#  'pc': np.int64(1538),
#  'xma': np.int64(2460),
#  'tree': np.int64(2176),
#  'burn': np.int64(230),
#  'congratul': np.int64(411),
#  'mo': np.int64(1329),
#  'wherev': np.int64(2388),
#  'mani happi': np.int64(1257),
#  'hope good': np.int64(964),
#  'good week': np.int64(840),
#  'bitch': np.int64(176),
#  'bu': np.int64(223),
#  'thnk': np.int64(2107),
#  'wrong': np.int64(2446),
#  'call us': np.int64(269),
#  'lovabl': np.int64(1204),
#  'bcum': np.int64(150),
#  'angri': np.int64(62),
#  'dnt': np.int64(543),
#  'serious': np.int64(1845),
#  'coz': np.int64(442),
#  'childish': np.int64(337),
#  'deep': np.int64(506),
#  'nice': np.int64(1425),
#  'wen ur': np.int64(2380),
#  'luv kettoda': np.int64(1231),
#  'nice day': np.int64(1426),
#  'day da': np.int64(490),
#  'high': np.int64(938),
#  'fren': np.int64(730),
#  'bye': np.int64(235),
#  'sweet dream': np.int64(2039),
#  'ahmad': np.int64(37),
#  'begin': np.int64(160),
#  'second': np.int64(1810),
#  'closer': np.int64(365),
#  'side': np.int64(1875),
#  'love much': np.int64(1210),
#  'happi new': np.int64(908),
#  'new year': np.int64(1420),
#  'see': np.int64(1815),
#  'shop': np.int64(1864),
#  'spree': np.int64(1964),
#  'shop spree': np.int64(1865),
#  'flower': np.int64(695),
#  'touch': np.int64(2166),
#  'man': np.int64(1252),
#  'last': np.int64(1111),
#  'wife': np.int64(2395),
#  'nt': np.int64(1452),
#  'parent': np.int64(1523),
#  'kid': np.int64(1083),
#  'colleagu': np.int64(377),
#  'sad stori': np.int64(1773),
#  'stori man': np.int64(2000),
#  'man last': np.int64(1253),
#  'last week': np.int64(1114),
#  'week day': np.int64(2363),
#  'day wife': np.int64(496),
#  'wife nt': np.int64(2396),
#  'nt wish': np.int64(1453),
#  'wish parent': np.int64(2409),
#  'parent forgot': np.int64(1524),
#  'forgot kid': np.int64(705),
#  'kid went': np.int64(1084),
#  'went work': np.int64(2382),
#  'work even': np.int64(2425),
#  'even colleagu': np.int64(621),
#  'colleagu wish': np.int64(379),
#  'fyi': np.int64(750),
#  'ride': np.int64(1747),
#  'earli': np.int64(578),
#  'crash': np.int64(446),
#  'tonight': np.int64(2158),
#  'easi': np.int64(580),
#  'medic': np.int64(1283),
#  'insur': np.int64(1033),
#  'abl': np.int64(2),
#  'deliv': np.int64(512),
#  'basic': np.int64(144),
#  'current': np.int64(463),
#  'til': np.int64(2122),
#  'major': np.int64(1247),
#  'guid': np.int64(887),
#  'medic insur': np.int64(1284),
#  'beer': np.int64(157),
#  'wine': np.int64(2403),
#  'log': np.int64(1184),
#  'later tonight': np.int64(1119),
#  'includ': np.int64(1022),
#  'find way': np.int64(683),
#  'nd': np.int64(1401),
#  'attempt': np.int64(109),
#  'yesterday': np.int64(2485),
#  'nd attempt': np.int64(1402),
#  'attempt contact': np.int64(110),
#  'claim call': np.int64(347),
#  'dunno': np.int64(575),
#  ...}

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
spam_detect_model = MultinomialNB().fit(X_train,y_train)

# %%
y_pred=spam_detect_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,classification_report

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9820627802690582

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.95      0.91      0.93       137
#         True       0.99      0.99      0.99       978
#
#     accuracy                           0.98      1115
#    macro avg       0.97      0.95      0.96      1115
# weighted avg       0.98      0.98      0.98      1115
