# %%
# %pip install nltk
# checking
# Out:
# Requirement already satisfied: nltk in d:\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: click in d:\anaconda3\lib\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in d:\anaconda3\lib\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in d:\anaconda3\lib\site-packages (from nltk) (2025.9.1)
# Requirement already satisfied: tqdm in d:\anaconda3\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in d:\anaconda3\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
corpus = """Hello welcome, Ayush kashyap's this side and i love tuning ml models and build some nice rag systems.
I am an atlhete also! and i love travelling.
"""

# %%
print(corpus)
# Out:
# Hello welcome, Ayush kashyap's this side and i love tuning ml models and build some nice rag systems.
# I am an atlhete also! and i love travelling.

# %% [markdown]
# # Tokenization
# ## Converting : paragraph --> sentence

# %%
import nltk

# %%
nltk.download("punkt_tab")
# Out:
# [nltk_data] Downloading package punkt_tab to C:\Users\Ayush
# [nltk_data]     Kashyap\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.tokenize import sent_tokenize

# %%
documents = sent_tokenize(corpus)

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
# Hello welcome, Ayush kashyap's this side and i love tuning ml models and build some nice rag systems.
# I am an atlhete also!
# and i love travelling.

# %% [markdown]
# # Tokenization
# ## Paragraph --> words
# ## sentence --> words

# %%
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  ',',
#  'Ayush',
#  'kashyap',
#  "'s",
#  'this',
#  'side',
#  'and',
#  'i',
#  'love',
#  'tuning',
#  'ml',
#  'models',
#  'and',
#  'build',
#  'some',
#  'nice',
#  'rag',
#  'systems',
#  '.',
#  'I',
#  'am',
#  'an',
#  'atlhete',
#  'also',
#  '!',
#  'and',
#  'i',
#  'love',
#  'travelling',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', 'welcome', ',', 'Ayush', 'kashyap', "'s", 'this', 'side', 'and', 'i', 'love', 'tuning', 'ml', 'models', 'and', 'build', 'some', 'nice', 'rag', 'systems', '.']
# ['I', 'am', 'an', 'atlhete', 'also', '!']
# ['and', 'i', 'love', 'travelling', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  ',',
#  'Ayush',
#  'kashyap',
#  "'",
#  's',
#  'this',
#  'side',
#  'and',
#  'i',
#  'love',
#  'tuning',
#  'ml',
#  'models',
#  'and',
#  'build',
#  'some',
#  'nice',
#  'rag',
#  'systems',
#  '.',
#  'I',
#  'am',
#  'an',
#  'atlhete',
#  'also',
#  '!',
#  'and',
#  'i',
#  'love',
#  'travelling',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer = TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  ',',
#  'Ayush',
#  'kashyap',
#  "'s",
#  'this',
#  'side',
#  'and',
#  'i',
#  'love',
#  'tuning',
#  'ml',
#  'models',
#  'and',
#  'build',
#  'some',
#  'nice',
#  'rag',
#  'systems.',
#  'I',
#  'am',
#  'an',
#  'atlhete',
#  'also',
#  '!',
#  'and',
#  'i',
#  'love',
#  'travelling',
#  '.']
